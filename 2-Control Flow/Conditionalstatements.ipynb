# %%
## if Statement
 
age=20

if age>=18:
    print("You are eligible to vote.")
# Out:
# You are eligible to vote.

# %%
# else Statement
# The else statement executes a block of code if the condition in the if statement is False.
age=16

if age>=18:
    print("You are eligible to vote.")
else:
    print("You are a minor")
# Out:
# You are a minor

# %%
## elif Statement
## The elif statement allows you to check multiple conditions. It stands for "else if"

age=20

if age<13:
    print("You are a child.")
elif age<18:
    print("You are a teenager.")
else:
    print("You are an adult.")
# Out:
# You are an adult.

# %%
## Nested Conditional statements
# You can place one or more if, elif, or else statements inside another if, elif, or else statement to create nested conditonal statements.

num= int(input("Enter a number"))

if num>0:
    print("The number is positive")
    if num%2==0:
        print("The number is even")
    else:
        print("The number is odd")
else:
    print("The number is 0 or negative")
# Out:
# The number is 0 or negative

# %% [markdown]
# ### 1. Leap Year

# %%
year= int(input("Enter a year"))

if year%4==0:
    if year%100==0:
        if year%400==0:
            print(f"{year} is a leap year")
        else:
            print(f"{year} is not a leap year")
    else:
        print(f"{year} is a leap year")
else:
    print(f"{year} is not a leap year")
# Out:
# 1900 is not a leap year

# %% [markdown]
# ### 2. Simple Calculator

# %%
num1 = float(input("Enter first number"))
num2 = float(input("Enter second number"))
operation = input("Enter operation (+, -, *, /)")

if operation =='+':
    print(f"{num1} + {num2} = {num1+num2}")
elif operation =='-':
    print(f"{num1} -{num2} = {num1-num2}")
elif operation =='*':
    print(f"{num1} * {num2} = {num1*num2}")
elif operation =='/':
    if num2!=0:
        print(f"{num1} / {num2} = {num1/num2}")
    else:
        print("Division by zero is not allowed")
else:
    print("Invalid Operation.")
# Out:
# 5.0 + 2.0 = 7.0

# %% [markdown]
# 3. Determine the ticket price based on age and whether the person is a student.

# %%
age= int(input("Enter your age"))
is_student= input("Are you a student? (yes/no)").lower()

if age<5:
    price= "Free"
elif age<=12:
    price= "$10"
elif age<=17:
    if is_student=="yes":
        price="$12"
    else:
        price= "$15"
elif age<=64:
    if is_student=="yes":
        price= "$18"
    else:
        price="$20"
print(f"The ticket price is {price}")
# Out:
# The ticket price is $20
