# %%
## Integer Example

age=23
type(age)
# Out:
# int

# %%
## Floating point datatype

height=5.3
type(height)
# Out:
# float

# %%
## String Datatype 

name="Debangshi"
type(name)
# Out:
# str

# %%
## Boolean Dtatype

True
type(True)

is_false= False
type(is_false)
# Out:
# bool

# %%
##by default python considers bool() as false if the value is 0, empty string, empty list, empty tuple, empty dictionary, None. Otherwise it considers it as True.

bool()
# Out:
# False

# %%
a=10
b=10
print(a==b)
type(a==b)
# Out:
# True
# bool

# %%
## common errors

result="hello" + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 ## common errors
#       2
# ----> 3 result="hello" + 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
result="hello" + str(5)
print(result)
# Out:
# hello5
